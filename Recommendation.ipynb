# %%
import pandas as pd
import numpy as np
import pyfpgrowth as pf

# %%
transactions = pd.read_csv('scripts/fpm-final.tsv', sep='\t', names = ['tid', 'asin', 'type', 'similar'])

# %%
transactions = transactions.drop(transactions[transactions.type != 'Book'].index)
transactions
# Out:
#            tid        asin  type  \
# 0            1  0827229534  Book
# 1            2  0738700797  Book
# 2            3  0486287785  Book
# 3            4  0842328327  Book
# 4            5  1577943082  Book
# 5            6  0486220125  Book
# 7            8  0231118597  Book
# 8            9  1859677800  Book
# 9           10  0375709363  Book
# 10          11  0871318237  Book
# 11          12  1590770218  Book
# 12          13  0313230269  Book
# 14          15  1559362022  Book
# 15          16  0195110382  Book
# 16          17  0849311012  Book
# 18          19  078510870X  Book
# 19          20  3895780812  Book
# 22          23  0393049388  Book
# 23          24  0553525476  Book
# 24          25  0939165252  Book
# 25          26  1590930509  Book
# 26          27  0231096704  Book
# 27          28  1893732290  Book
# 28          29  0781718791  Book
# 29          30  0471150274  Book
# 30          31  0895872218  Book
# 31          32  0761116982  Book
# ...

# %%
asin_main = transactions.asin
similar = transactions.similar
