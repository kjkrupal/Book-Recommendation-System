# %%
filename = '../../Datasets/amazon-meta.txt'
#filename = '../Amazon-Co-Purchasing-Pattern/Dataset/sample-meta.txt'
tsv_file_name = '../../Datasets/fpm-data.tsv'

count = 0

tid = None

file = open(filename, 'r')
tsv_file = open(tsv_file_name, 'w+')
#tsv_file.write('product\tco-purchased\n')
new_line = ''

for line in file:
    if(count < 7):
        count = count + 1
        continue
    if(line == '\n'):
        continue
    
    label = line.partition(':')[0]

    if(label == 'Id'):
        line = line.replace(' ', '')
        line = line.split(':')
        tid = line[1].split('\n')
        tid = tid[0]
        #print("TID: " + str(tid) + " ")
        new_line = new_line + tid + '\t'
    
    if('discontinued product' in line):
        new_line = ''
        continue

    if(label == 'ASIN'):
        line = line.replace(' ', '')
        line = line.split(':')
        asin = line[1].split('\n')
        asin = asin[0]
        #print("ASIN: " + str(asin))
        new_line = new_line + asin + '\n'

    if(label == '  similar'):
        line = line.split(':')
        line = line[1].replace('  ', ',')
        line = line.split('\n')
        line = line[0].replace(' ', '')
        line = line.split(',')
        for i in range(0, len(line)):
            if(i == 0):
                continue
            new_line = new_line + tid + '\t' + line[i] + '\n'
        tsv_file.write(new_line[:-1] + '\n')
        new_line = ''

# %%
filename = '../../Datasets/amazon-meta.txt'
tsv_file_name = '../../Datasets/fpm.tsv'

count = 0

file = open(filename, 'r')
tsv_file = open(tsv_file_name, 'w+')
new_line = ''

tsv_file.write('product\tsimilar\n')

for line in file:
    if(count < 7):
        count = count + 1
        continue
    if(line == '\n'):
        continue
    
    label = line.partition(':')[0]

    if(label == 'Id'):
        line = line.replace(' ', '')
        line = line.split(':')
        tid = line[1].split('\n')
        tid = tid[0]
        #print("TID: " + str(tid) + " ")
        new_line = new_line + tid + '\t'
    
    if('discontinued product' in line):
        new_line = ''
        continue

    if(label == 'ASIN'):
        line = line.replace(' ', '')
        line = line.split(':')
        asin = line[1].split('\n')
        asin = asin[0]
        #print("ASIN: " + str(asin))
        new_line = new_line + asin + '\t'

    if(label == '  similar'):
        line = line.split(':')
        line = line[1].replace('  ', ',')
        line = line.split('\n')
        line = line[0].replace(' ', '')
        line = line.split(',')
        for i in range(0, len(line)):
            if(i == 0):
                continue
            new_line = new_line + line[i] + ','
        tsv_file.write(new_line[:-1] + '\n')
        new_line = ''

# %%
import pandas as pd

# %%
fpm = pd.read_csv('../../Datasets/fpm.tsv', sep='\t')

# %%
fpm
# Out:
#            product                                            similar
# 1       0827229534  0804215715,156101074X,0687023955,0687074231,08...
# 2       0738700797  0738700827,1567184960,1567182836,0738700525,07...
# 3       0486287785                                                NaN
# 4       0842328327  0842328130,0830818138,0842330313,0842328610,08...
# 5       1577943082  157794349X,0892749504,1577941829,0892749563,15...
# 6       0486220125  0486401960,0452283612,0486229076,0714840343,03...
# 7       B00000AU3R  B00002616C,B0000261KX,B00006AM8D,B000059OB9,B0...
# 8       0231118597  B000067D0Y,0375727191,080148605X,1560232579,03...
# 9       1859677800                                                NaN
# 10      0375709363  039474067X,0679730672,0679750541,1400030668,08...
# 11      0871318237  1591200695,0060984341,0553577514,1571742972,09...
